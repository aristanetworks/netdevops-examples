# %% [markdown]
# ## Imports

# %%
import pandas as pd 
from pybatfish.client.commands import *
from pybatfish.datamodel import *
from pybatfish.datamodel.answer import *
from pybatfish.datamodel.flow import *
from pybatfish.question import *
from pybatfish.question import bfq

# %% [markdown]
# ### Set  pandas defaults

# %%
pd.set_option('display.max_colwidth', 2000)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Batfish Sessions

# %%
bf_session.host = 'localhost'

# %%
bf_set_network('atd_avd')
# Out:
# 'atd_avd'

# %% [markdown]
# ## Setup Snapshot

# %%
SNAPSHOT_DIR = './atd-avd/snapshot'

# %%
bf_init_snapshot(SNAPSHOT_DIR, name='atd_avd_snapsot_10_18_21', overwrite=True)
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: CHECKINGSTATUS
# .... no task information
# status: ASSIGNED
# .... 2021-10-18 15:29:37.186000-07:00 Parse network configs 0 / 6.
# status: ASSIGNED
# .... 2021-10-18 15:29:37.186000-07:00 Parse network configs 0 / 6.
# status: ASSIGNED
# .... 2021-10-18 15:29:37.186000-07:00 Parse network configs 0 / 6.
# status: ASSIGNED
# .... 2021-10-18 15:29:37.186000-07:00 Parse network configs 0 / 6.
# status: ASSIGNED
# .... 2021-10-18 15:29:37.186000-07:00 Convert configurations to vendor-independent format 1 / 7.
# status: TERMINATEDNORMALLY
# .... 2021-10-18 15:29:37.186000-07:00 Deserializing objects of type 'org.batfish.datamodel.Configuration' from files 6 / 6.
# Default snapshot is now set to atd_avd_snapsot_10_18_21
# status: TRYINGTOASSIGN
# .... no task information
# status: ASSIGNED
# .... 2021-10-18 15:29:40.358000-07:00 Parse environment BGP tables.
# status: TERMINATEDNORMALLY
# .... 2021-10-18 15:29:40.358000-07:00 Parse environment BGP tables.
# Your snapshot was successfully initialized but Batfish failed to fully recognized some lines in one or more input files. Some unrecognized configuration lines are not uncommon for new networks, and it is often fine to proceed with further analysis. You can help the Batfish developers improve support for your network by running:
#
#     bf_upload_diagnostics(dry_run=False, contact_info='<optional email address>')
#
# to share private, anonymized information. For more information, see the documentation with:
#
#     help(bf_upload_diagnostics)
# 'atd_avd_snapsot_10_18_21'

# %%
bf_set_snapshot('atd_avd_snapsot_10_18_21')
# Out:
# Default snapshot is now set to atd_avd_snapsot_10_18_21
# 'atd_avd_snapsot_10_18_21'

# %% [markdown]
# ## Load Batfish Questions

# %%
load_questions()
# Out:
# Successfully loaded 67 questions from remote
# Successfully loaded 67 questions from remote

# %%
bfq.initIssues().answer()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: ASSIGNED
# .... 2021-10-18 15:30:15.478000-07:00 Begin job.
# status: TERMINATEDNORMALLY
# .... 2021-10-18 15:30:15.478000-07:00 Begin job.
#    Nodes                                       Source_Lines           Type  \
# 0   None                          [configs/leaf1.cfg:[158]]  Parse warning
# 1   None  [configs/leaf1.cfg:[161], configs/leaf3.cfg:[1...  Parse warning
# 2   None  [configs/leaf1.cfg:[17], configs/leaf3.cfg:[17...  Parse warning
# 3   None  [configs/leaf1.cfg:[185], configs/leaf3.cfg:[1...  Parse warning
# 4   None  [configs/leaf1.cfg:[186], configs/leaf3.cfg:[1...  Parse warning
# 5   None  [configs/leaf1.cfg:[19], configs/leaf3.cfg:[19...  Parse warning
# 6   None  [configs/leaf1.cfg:[206, 212], configs/leaf3.c...  Parse warning
# 7   None  [configs/leaf1.cfg:[231, 237], configs/leaf3.c...  Parse warning
# 8   None  [configs/leaf1.cfg:[25], configs/leaf3.cfg:[25...  Parse warning
# 9   None  [configs/leaf1.cfg:[7], configs/leaf3.cfg:[7],...  Parse warning
# 10  None  [configs/leaf1.cfg:[9], configs/leaf3.cfg:[9],...  Parse warning
# 11  None                          [configs/leaf2.cfg:[158]]  Parse warning
# 12  None                          [configs/leaf3.cfg:[158]]  Parse warning
# 13  None                          [configs/leaf4.cfg:[158]]  Parse warning
#
#                                               Details  \
# 0                         This syntax is unrecognized
# 1                         This syntax is unrecognized
# 2                         This syntax is unrecognized
# 3                         This syntax is unrecognized
# 4                         This syntax is unrecognized
# 5                         This syntax is unrecognized
# 6   Batfish does not limit the number of routes re...
# 7             This feature is not currently supported
# 8                         This syntax is unrecognized
# 9                         This syntax is unrecognized
# 10                        This syntax is unrecognized
# 11                        This syntax is unrecognized
# 12                        This syntax is unrecognized
# 13                        This syntax is unrecognized
#
#                                             Line_Text  \
# 0   ip address virtual source-nat vrf Tenant_A_OP_...
# 1                              no ip routing vrf MGMT
# 2                                  dns domain atd.lab
# 3                                          router bfd
# 4     multihop interval 1200 min-rx 1200 multiplier 3
# 5   radius-server host 192.168.0.1 vrf MGMT key 7 ...
# 6                                maximum-routes 12000
# 7                                redistribute learned
# 8                  no spanning-tree vlan-id 4093-4094
# 9       vlan internal order ascending range 1006 1199
# 10                transceiver qsfp default-mode 4x10G
# 11  ip address virtual source-nat vrf Tenant_A_OP_...
# 12  ip address virtual source-nat vrf Tenant_A_OP_...
# 13  ip address virtual source-nat vrf Tenant_A_OP_...
#
#                                        Parser_Context
# 0                       [stanza arista_configuration]
# 1                       [stanza arista_configuration]
# 2                              [arista_configuration]
# 3                       [stanza arista_configuration]
# 4                              [arista_configuration]
# 5                              [arista_configuration]
# 6   [eos_rbinc_maximum_routes eos_rbi_neighbor_com...
# 7   [eos_rb_vlan_tail_redistribute eos_rb_vlan_tai...
# 8       [s_spanning_tree stanza arista_configuration]
# 9                       [stanza arista_configuration]
# 10                             [arista_configuration]
# 11                      [stanza arista_configuration]
# 12                      [stanza arista_configuration]
# 13                      [stanza arista_configuration]

# %% [markdown]
# ## Batfish questions on EVPN/VXLAN

# %% [markdown]
# ### VXLAN VNI Properties

# %%
vxlan_vni_props = bfq.vxlanVniProperties().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: TERMINATEDNORMALLY
# .... 2021-10-18 15:48:39.100000-07:00 Begin job.

# %%
vxlan_vni_props
# Out:
#     Node               VRF    VNI Local_VTEP_IP Multicast_Group VLAN  \
# 0  leaf1  Tenant_A_OP_Zone  10110   192.0.254.3            None  110
# 1  leaf2           default  55160   192.0.254.3            None  160
# 2  leaf3  Tenant_A_OP_Zone  10110   192.0.254.5            None  110
# 3  leaf4           default  55160   192.0.254.5            None  160
# 4  leaf1           default  55160   192.0.254.3            None  160
# 5  leaf4  Tenant_A_OP_Zone  10110   192.0.254.5            None  110
# 6  leaf2  Tenant_A_OP_Zone  10110   192.0.254.3            None  110
# 7  leaf3           default  55160   192.0.254.5            None  160
#
#    VTEP_Flood_List VXLAN_Port
# 0  ['192.0.254.5']       4789
# 1               []       4789
# 2  ['192.0.254.3']       4789
# 3               []       4789
# 4               []       4789
# 5  ['192.0.254.3']       4789
# 6  ['192.0.254.5']       4789
# 7               []       4789

# %% [markdown]
# ### L3 EVPN VNI Properties

# %%
l3_evpn_vni_props = bfq.evpnL3VniProperties().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: TERMINATEDNORMALLY
# .... 2021-10-18 15:53:37.542000-07:00 Begin job.

# %%
l3_evpn_vni_props
# Out:
#     Node               VRF VNI Route_Distinguisher Import_Route_Target  \
# 0  leaf1  Tenant_A_OP_Zone  10      192.0.255.3:10               10:10
# 1  leaf2  Tenant_A_OP_Zone  10      192.0.255.4:10               10:10
# 2  leaf3  Tenant_A_OP_Zone  10      192.0.255.5:10               10:10
# 3  leaf4  Tenant_A_OP_Zone  10      192.0.255.6:10               10:10
#
#   Export_Route_Target
# 0               10:10
# 1               10:10
# 2               10:10
# 3               10:10

# %% [markdown]
# ### VXLAN Edges

# %%
vxlan_edges = bfq.vxlanEdges().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: ASSIGNED
# .... 2021-10-18 15:55:29.934000-07:00 Begin job.
# status: ASSIGNED
# .... 2021-10-18 15:55:29.934000-07:00 Begin job.
# status: TERMINATEDNORMALLY
# .... 2021-10-18 15:55:29.934000-07:00 Begin job.

# %%
vxlan_edges
# Out:
#      VNI   Node Remote_Node VTEP_Address Remote_VTEP_Address VLAN Remote_VLAN  \
# 0  10110  leaf1       leaf3  192.0.254.3         192.0.254.5  110         110
# 1  10110  leaf3       leaf1  192.0.254.5         192.0.254.3  110         110
# 2  10110  leaf1       leaf4  192.0.254.3         192.0.254.5  110         110
# 3  10110  leaf4       leaf1  192.0.254.5         192.0.254.3  110         110
# 4  10110  leaf2       leaf4  192.0.254.3         192.0.254.5  110         110
# 5  10110  leaf4       leaf2  192.0.254.5         192.0.254.3  110         110
# 6  10110  leaf2       leaf3  192.0.254.3         192.0.254.5  110         110
# 7  10110  leaf3       leaf2  192.0.254.5         192.0.254.3  110         110
#
#   UDP_Port Multicast_Group
# 0     4789            None
# 1     4789            None
# 2     4789            None
# 3     4789            None
# 4     4789            None
# 5     4789            None
# 6     4789            None
# 7     4789            None

# %% [markdown]
# ### Dataframe query example

# %%
[vxlan_edges[vxlan_edges['Node'] == 'leaf1']]
# Out:
# [     VNI   Node Remote_Node VTEP_Address Remote_VTEP_Address VLAN Remote_VLAN  \
#  0  10110  leaf1       leaf3  192.0.254.3         192.0.254.5  110         110
#  2  10110  leaf1       leaf4  192.0.254.3         192.0.254.5  110         110
#
#    UDP_Port Multicast_Group
#  0     4789            None
#  2     4789            None  ]

# %% [markdown]
# ## Topology Questions

# %% [markdown]
# ### L3 Topology

# %%
l3_topo = bfq.layer3Edges().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: TERMINATEDNORMALLY
# .... 2021-10-18 16:15:21.770000-07:00 Begin job.

# %%
l3_topo
# Out:
#             Interface                IPs   Remote_Interface         Remote_IPs
# 0    leaf1[Ethernet3]   ['172.31.255.3']  spine2[Ethernet2]   ['172.31.255.2']
# 1    leaf2[Ethernet2]   ['172.31.255.5']  spine1[Ethernet3]   ['172.31.255.4']
# 2    leaf3[Ethernet2]   ['172.31.255.9']  spine1[Ethernet4]   ['172.31.255.8']
# 3    leaf3[Ethernet3]  ['172.31.255.11']  spine2[Ethernet4]  ['172.31.255.10']
# 4   spine1[Ethernet3]   ['172.31.255.4']   leaf2[Ethernet2]   ['172.31.255.5']
# 5   spine1[Ethernet5]  ['172.31.255.12']   leaf4[Ethernet2]  ['172.31.255.13']
# 6   spine2[Ethernet4]  ['172.31.255.10']   leaf3[Ethernet3]  ['172.31.255.11']
# 7   spine2[Ethernet5]  ['172.31.255.14']   leaf4[Ethernet3]  ['172.31.255.15']
# 8    leaf4[Ethernet3]  ['172.31.255.15']  spine2[Ethernet5]  ['172.31.255.14']
# 9   spine1[Ethernet2]   ['172.31.255.0']   leaf1[Ethernet2]   ['172.31.255.1']
# 10    leaf1[Vlan3009]   ['10.255.251.0']    leaf2[Vlan4093]   ['10.255.251.1']
# 11    leaf2[Vlan3009]   ['10.255.251.1']    leaf1[Vlan4093]   ['10.255.251.0']
# 12   leaf1[Ethernet2]   ['172.31.255.1']  spine1[Ethernet2]   ['172.31.255.0']
# 13    leaf1[Vlan4093]   ['10.255.251.0']    leaf2[Vlan3009]   ['10.255.251.1']
# 14    leaf2[Vlan4093]   ['10.255.251.1']    leaf1[Vlan3009]   ['10.255.251.0']
# 15  spine2[Ethernet3]   ['172.31.255.6']   leaf2[Ethernet3]   ['172.31.255.7']
# 16  spine2[Ethernet2]   ['172.31.255.2']   leaf1[Ethernet3]   ['172.31.255.3']
# 17    leaf3[Vlan3009]   ['10.255.251.4']    leaf4[Vlan3009]   ['10.255.251.5']
# 18    leaf4[Vlan3009]   ['10.255.251.5']    leaf3[Vlan3009]   ['10.255.251.4']
# 19    leaf3[Vlan4093]   ['10.255.251.4']    leaf4[Vlan3009]   ['10.255.251.5']
# 20    leaf4[Vlan4093]   ['10.255.251.5']    leaf3[Vlan3009]   ['10.255.251.4']
# 21    leaf1[Vlan4094]   ['10.255.252.0']    leaf2[Vlan4094]   ['10.255.252.1']
# 22    leaf3[Vlan4093]   ['10.255.251.4']    leaf4[Vlan4093]   ['10.255.251.5']
# 23    leaf4[Vlan4093]   ['10.255.251.5']    leaf3[Vlan4093]   ['10.255.251.4']
# 24    leaf3[Vlan3009]   ['10.255.251.4']    leaf4[Vlan4093]   ['10.255.251.5']
# 25    leaf4[Vlan3009]   ['10.255.251.5']    leaf3[Vlan4093]   ['10.255.251.4']
# 26   leaf2[Ethernet3]   ['172.31.255.7']  spine2[Ethernet3]   ['172.31.255.6']
# 27    leaf4[Vlan4094]   ['10.255.252.5']    leaf3[Vlan4094]   ['10.255.252.4']
# 28    leaf1[Vlan4093]   ['10.255.251.0']    leaf2[Vlan4093]   ['10.255.251.1']
# 29    leaf2[Vlan4093]   ['10.255.251.1']    leaf1[Vlan4093]   ['10.255.251.0']
# 30    leaf1[Vlan3009]   ['10.255.251.0']    leaf2[Vlan3009]   ['10.255.251.1']
# 31    leaf2[Vlan3009]   ['10.255.251.1']    leaf1[Vlan3009]   ['10.255.251.0']
# 32    leaf2[Vlan4094]   ['10.255.252.1']    leaf1[Vlan4094]   ['10.255.252.0']
# 33    leaf3[Vlan4094]   ['10.255.252.4']    leaf4[Vlan4094]   ['10.255.252.5']
# 34   leaf4[Ethernet2]  ['172.31.255.13']  spine1[Ethernet5]  ['172.31.255.12']
# 35  spine1[Ethernet4]   ['172.31.255.8']   leaf3[Ethernet2]   ['172.31.255.9']

# %% [markdown]
# ### L1 Topology

# %%
l1_topo = bfq.layer1Edges().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: TERMINATEDNORMALLY
# .... 2021-10-18 16:16:40.056000-07:00 Begin job.

# %%
l1_topo
# Out:
# Empty DataFrame
# Columns: [Interface, Remote_Interface]
# Index: []

# %% [markdown]
# ## Routing Protocols Questions

# %% [markdown]
# ### BGP Session Compatibility

# %%
bgp_session_compatibility = bfq.bgpSessionCompatibility().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: ASSIGNED
# .... 2021-10-18 16:49:34.740000-07:00 Begin job.
# status: TERMINATEDNORMALLY
# .... 2021-10-18 16:49:34.740000-07:00 Deserializing objects of type 'org.batfish.datamodel.Configuration' from files 6 / 6.

# %%
bgp_session_compatibility
# Out:
#       Node               VRF Local_AS Local_Interface       Local_IP  \
# 0    leaf1  Tenant_A_OP_Zone    65101            None   10.255.251.0
# 1    leaf1           default    65101            None   10.255.251.0
# 2    leaf1           default    65101            None   172.31.255.1
# 3    leaf1           default    65101            None   172.31.255.3
# 4    leaf1           default    65101            None    192.0.255.3
# 5    leaf1           default    65101            None    192.0.255.3
# 6    leaf2  Tenant_A_OP_Zone    65101            None   10.255.251.1
# 7    leaf2           default    65101            None   10.255.251.1
# 8    leaf2           default    65101            None   172.31.255.5
# 9    leaf2           default    65101            None   172.31.255.7
# 10   leaf2           default    65101            None    192.0.255.4
# 11   leaf2           default    65101            None    192.0.255.4
# 12   leaf3  Tenant_A_OP_Zone    65102            None   10.255.251.4
# 13   leaf3           default    65102            None   10.255.251.4
# 14   leaf3           default    65102            None   172.31.255.9
# 15   leaf3           default    65102            None  172.31.255.11
# 16   leaf3           default    65102            None    192.0.255.5
# 17   leaf3           default    65102            None    192.0.255.5
# 18   leaf4  Tenant_A_OP_Zone    65102            None   10.255.251.5
# 19   leaf4           default    65102            None   10.255.251.5
# 20   leaf4           default    65102            None  172.31.255.13
# 21   leaf4           default    65102            None  172.31.255.15
# 22   leaf4           default    65102            None    192.0.255.6
# 23   leaf4           default    65102            None    192.0.255.6
# 24  spine1           default    65001            None   172.31.255.0
# 25  spine1           default    65001            None   172.31.255.4
# 26  spine1           default    65001            None   172.31.255.8
# 27  spine1           default    65001            None  172.31.255.12
# 28  spine1           default    65001            None    192.0.255.1
# 29  spine1           default    65001            None    192.0.255.1
# 30  spine1           default    65001            None    192.0.255.1
# 31  spine1           default    65001            None    192.0.255.1
# 32  spine2           default    65001            None   172.31.255.2
# 33  spine2           default    65001            None   172.31.255.6
# 34  spine2           default    65001            None  172.31.255.10
# 35  spine2           default    65001            None  172.31.255.14
# 36  spine2           default    65001            None    192.0.255.2
# 37  spine2           default    65001            None    192.0.255.2
# 38  spine2           default    65001            None    192.0.255.2
# 39  spine2           default    65001            None    192.0.255.2
#
#    Remote_AS Remote_Node Remote_Interface      Remote_IP  Address_Families  \
# 0      65101        None             None   10.255.251.1                []
# 1      65101        None             None   10.255.251.1                []
# 2      65001      spine1             None   172.31.255.0  ['IPV4_UNICAST']
# 3      65001      spine2             None   172.31.255.2  ['IPV4_UNICAST']
# 4      65001      spine1             None    192.0.255.1          ['EVPN']
# 5      65001      spine2             None    192.0.255.2          ['EVPN']
# 6      65101        None             None   10.255.251.0                []
# 7      65101        None             None   10.255.251.0                []
# 8      65001      spine1             None   172.31.255.4  ['IPV4_UNICAST']
# 9      65001      spine2             None   172.31.255.6  ['IPV4_UNICAST']
# 10     65001      spine1             None    192.0.255.1          ['EVPN']
# 11     65001      spine2             None    192.0.255.2          ['EVPN']
# 12     65102        None             None   10.255.251.5                []
# 13     65102        None             None   10.255.251.5                []
# 14     65001      spine1             None   172.31.255.8  ['IPV4_UNICAST']
# 15     65001      spine2             None  172.31.255.10  ['IPV4_UNICAST']
# 16     65001      spine1             None    192.0.255.1          ['EVPN']
# 17     65001      spine2             None    192.0.255.2          ['EVPN']
# 18     65102        None             None   10.255.251.4                []
# 19     65102        None             None   10.255.251.4                []
# 20     65001      spine1             None  172.31.255.12  ['IPV4_UNICAST']
# 21     65001      spine2             None  172.31.255.14  ['IPV4_UNICAST']
# 22     65001      spine1             None    192.0.255.1          ['EVPN']
# 23     65001      spine2             None    192.0.255.2          ['EVPN']
# 24     65101       leaf1             None   172.31.255.1  ['IPV4_UNICAST']
# 25     65101       leaf2             None   172.31.255.5  ['IPV4_UNICAST']
# 26     65102       leaf3             None   172.31.255.9  ['IPV4_UNICAST']
# 27     65102       leaf4             None  172.31.255.13  ['IPV4_UNICAST']
# 28     65101       leaf1             None    192.0.255.3          ['EVPN']
# 29     65101       leaf2             None    192.0.255.4          ['EVPN']
# 30     65102       leaf3             None    192.0.255.5          ['EVPN']
# 31     65102       leaf4             None    192.0.255.6          ['EVPN']
# 32     65101       leaf1             None   172.31.255.3  ['IPV4_UNICAST']
# 33     65101       leaf2             None   172.31.255.7  ['IPV4_UNICAST']
# 34     65102       leaf3             None  172.31.255.11  ['IPV4_UNICAST']
# 35     65102       leaf4             None  172.31.255.15  ['IPV4_UNICAST']
# 36     65101       leaf1             None    192.0.255.3          ['EVPN']
# 37     65101       leaf2             None    192.0.255.4          ['EVPN']
# 38     65102       leaf3             None    192.0.255.5          ['EVPN']
# 39     65102       leaf4             None    192.0.255.6          ['EVPN']
#
#       Session_Type Configured_Status
# 0             IBGP  MULTIPLE_REMOTES
# 1             IBGP  MULTIPLE_REMOTES
# 2   EBGP_SINGLEHOP      UNIQUE_MATCH
# 3   EBGP_SINGLEHOP      UNIQUE_MATCH
# 4    EBGP_MULTIHOP      UNIQUE_MATCH
# 5    EBGP_MULTIHOP      UNIQUE_MATCH
# 6             IBGP  MULTIPLE_REMOTES
# 7             IBGP  MULTIPLE_REMOTES
# 8   EBGP_SINGLEHOP      UNIQUE_MATCH
# 9   EBGP_SINGLEHOP      UNIQUE_MATCH
# 10   EBGP_MULTIHOP      UNIQUE_MATCH
# 11   EBGP_MULTIHOP      UNIQUE_MATCH
# 12            IBGP  MULTIPLE_REMOTES
# 13            IBGP  MULTIPLE_REMOTES
# 14  EBGP_SINGLEHOP      UNIQUE_MATCH
# 15  EBGP_SINGLEHOP      UNIQUE_MATCH
# 16   EBGP_MULTIHOP      UNIQUE_MATCH
# 17   EBGP_MULTIHOP      UNIQUE_MATCH
# 18            IBGP  MULTIPLE_REMOTES
# 19            IBGP  MULTIPLE_REMOTES
# 20  EBGP_SINGLEHOP      UNIQUE_MATCH
# 21  EBGP_SINGLEHOP      UNIQUE_MATCH
# 22   EBGP_MULTIHOP      UNIQUE_MATCH
# 23   EBGP_MULTIHOP      UNIQUE_MATCH
# 24  EBGP_SINGLEHOP      UNIQUE_MATCH
# 25  EBGP_SINGLEHOP      UNIQUE_MATCH
# 26  EBGP_SINGLEHOP      UNIQUE_MATCH
# 27  EBGP_SINGLEHOP      UNIQUE_MATCH
# 28   EBGP_MULTIHOP      UNIQUE_MATCH
# 29   EBGP_MULTIHOP      UNIQUE_MATCH
# 30   EBGP_MULTIHOP      UNIQUE_MATCH
# 31   EBGP_MULTIHOP      UNIQUE_MATCH
# 32  EBGP_SINGLEHOP      UNIQUE_MATCH
# 33  EBGP_SINGLEHOP      UNIQUE_MATCH
# 34  EBGP_SINGLEHOP      UNIQUE_MATCH
# 35  EBGP_SINGLEHOP      UNIQUE_MATCH
# 36   EBGP_MULTIHOP      UNIQUE_MATCH
# 37   EBGP_MULTIHOP      UNIQUE_MATCH
# 38   EBGP_MULTIHOP      UNIQUE_MATCH
# 39   EBGP_MULTIHOP      UNIQUE_MATCH

# %% [markdown]
# ### BGP Session Status

# %%
bgp_session_status = bfq.bgpSessionStatus().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: CHECKINGSTATUS
# .... no task information
# status: TERMINATEDNORMALLY
# .... 2021-10-18 16:53:24.994000-07:00 Begin job.

# %%
bgp_session_status
# Out:
#       Node               VRF Local_AS Local_Interface       Local_IP  \
# 0    leaf1  Tenant_A_OP_Zone    65101            None   10.255.251.0
# 1    leaf1           default    65101            None   10.255.251.0
# 2    leaf1           default    65101            None   172.31.255.1
# 3    leaf1           default    65101            None   172.31.255.3
# 4    leaf1           default    65101            None    192.0.255.3
# 5    leaf1           default    65101            None    192.0.255.3
# 6    leaf2  Tenant_A_OP_Zone    65101            None   10.255.251.1
# 7    leaf2           default    65101            None   10.255.251.1
# 8    leaf2           default    65101            None   172.31.255.5
# 9    leaf2           default    65101            None   172.31.255.7
# 10   leaf2           default    65101            None    192.0.255.4
# 11   leaf2           default    65101            None    192.0.255.4
# 12   leaf3  Tenant_A_OP_Zone    65102            None   10.255.251.4
# 13   leaf3           default    65102            None   10.255.251.4
# 14   leaf3           default    65102            None   172.31.255.9
# 15   leaf3           default    65102            None  172.31.255.11
# 16   leaf3           default    65102            None    192.0.255.5
# 17   leaf3           default    65102            None    192.0.255.5
# 18   leaf4  Tenant_A_OP_Zone    65102            None   10.255.251.5
# 19   leaf4           default    65102            None   10.255.251.5
# 20   leaf4           default    65102            None  172.31.255.13
# 21   leaf4           default    65102            None  172.31.255.15
# 22   leaf4           default    65102            None    192.0.255.6
# 23   leaf4           default    65102            None    192.0.255.6
# 24  spine1           default    65001            None   172.31.255.0
# 25  spine1           default    65001            None   172.31.255.4
# 26  spine1           default    65001            None   172.31.255.8
# 27  spine1           default    65001            None  172.31.255.12
# 28  spine1           default    65001            None    192.0.255.1
# 29  spine1           default    65001            None    192.0.255.1
# 30  spine1           default    65001            None    192.0.255.1
# 31  spine1           default    65001            None    192.0.255.1
# 32  spine2           default    65001            None   172.31.255.2
# 33  spine2           default    65001            None   172.31.255.6
# 34  spine2           default    65001            None  172.31.255.10
# 35  spine2           default    65001            None  172.31.255.14
# 36  spine2           default    65001            None    192.0.255.2
# 37  spine2           default    65001            None    192.0.255.2
# 38  spine2           default    65001            None    192.0.255.2
# 39  spine2           default    65001            None    192.0.255.2
#
#    Remote_AS Remote_Node Remote_Interface      Remote_IP  Address_Families  \
# 0      65101        None             None   10.255.251.1                []
# 1      65101        None             None   10.255.251.1                []
# 2      65001      spine1             None   172.31.255.0  ['IPV4_UNICAST']
# 3      65001      spine2             None   172.31.255.2  ['IPV4_UNICAST']
# 4      65001      spine1             None    192.0.255.1          ['EVPN']
# 5      65001      spine2             None    192.0.255.2          ['EVPN']
# 6      65101        None             None   10.255.251.0                []
# 7      65101        None             None   10.255.251.0                []
# 8      65001      spine1             None   172.31.255.4  ['IPV4_UNICAST']
# 9      65001      spine2             None   172.31.255.6  ['IPV4_UNICAST']
# 10     65001      spine1             None    192.0.255.1          ['EVPN']
# 11     65001      spine2             None    192.0.255.2          ['EVPN']
# 12     65102        None             None   10.255.251.5                []
# 13     65102        None             None   10.255.251.5                []
# 14     65001      spine1             None   172.31.255.8  ['IPV4_UNICAST']
# 15     65001      spine2             None  172.31.255.10  ['IPV4_UNICAST']
# 16     65001      spine1             None    192.0.255.1          ['EVPN']
# 17     65001      spine2             None    192.0.255.2          ['EVPN']
# 18     65102        None             None   10.255.251.4                []
# 19     65102        None             None   10.255.251.4                []
# 20     65001      spine1             None  172.31.255.12  ['IPV4_UNICAST']
# 21     65001      spine2             None  172.31.255.14  ['IPV4_UNICAST']
# 22     65001      spine1             None    192.0.255.1          ['EVPN']
# 23     65001      spine2             None    192.0.255.2          ['EVPN']
# 24     65101       leaf1             None   172.31.255.1  ['IPV4_UNICAST']
# 25     65101       leaf2             None   172.31.255.5  ['IPV4_UNICAST']
# 26     65102       leaf3             None   172.31.255.9  ['IPV4_UNICAST']
# 27     65102       leaf4             None  172.31.255.13  ['IPV4_UNICAST']
# 28     65101       leaf1             None    192.0.255.3          ['EVPN']
# 29     65101       leaf2             None    192.0.255.4          ['EVPN']
# 30     65102       leaf3             None    192.0.255.5          ['EVPN']
# 31     65102       leaf4             None    192.0.255.6          ['EVPN']
# 32     65101       leaf1             None   172.31.255.3  ['IPV4_UNICAST']
# 33     65101       leaf2             None   172.31.255.7  ['IPV4_UNICAST']
# 34     65102       leaf3             None  172.31.255.11  ['IPV4_UNICAST']
# 35     65102       leaf4             None  172.31.255.15  ['IPV4_UNICAST']
# 36     65101       leaf1             None    192.0.255.3          ['EVPN']
# 37     65101       leaf2             None    192.0.255.4          ['EVPN']
# 38     65102       leaf3             None    192.0.255.5          ['EVPN']
# 39     65102       leaf4             None    192.0.255.6          ['EVPN']
#
#       Session_Type Established_Status
# 0             IBGP     NOT_COMPATIBLE
# 1             IBGP     NOT_COMPATIBLE
# 2   EBGP_SINGLEHOP        ESTABLISHED
# 3   EBGP_SINGLEHOP        ESTABLISHED
# 4    EBGP_MULTIHOP        ESTABLISHED
# 5    EBGP_MULTIHOP        ESTABLISHED
# 6             IBGP     NOT_COMPATIBLE
# 7             IBGP     NOT_COMPATIBLE
# 8   EBGP_SINGLEHOP        ESTABLISHED
# 9   EBGP_SINGLEHOP        ESTABLISHED
# 10   EBGP_MULTIHOP        ESTABLISHED
# 11   EBGP_MULTIHOP        ESTABLISHED
# 12            IBGP     NOT_COMPATIBLE
# 13            IBGP     NOT_COMPATIBLE
# 14  EBGP_SINGLEHOP        ESTABLISHED
# 15  EBGP_SINGLEHOP        ESTABLISHED
# 16   EBGP_MULTIHOP        ESTABLISHED
# 17   EBGP_MULTIHOP        ESTABLISHED
# 18            IBGP     NOT_COMPATIBLE
# 19            IBGP     NOT_COMPATIBLE
# 20  EBGP_SINGLEHOP        ESTABLISHED
# 21  EBGP_SINGLEHOP        ESTABLISHED
# 22   EBGP_MULTIHOP        ESTABLISHED
# 23   EBGP_MULTIHOP        ESTABLISHED
# 24  EBGP_SINGLEHOP        ESTABLISHED
# 25  EBGP_SINGLEHOP        ESTABLISHED
# 26  EBGP_SINGLEHOP        ESTABLISHED
# 27  EBGP_SINGLEHOP        ESTABLISHED
# 28   EBGP_MULTIHOP        ESTABLISHED
# 29   EBGP_MULTIHOP        ESTABLISHED
# 30   EBGP_MULTIHOP        ESTABLISHED
# 31   EBGP_MULTIHOP        ESTABLISHED
# 32  EBGP_SINGLEHOP        ESTABLISHED
# 33  EBGP_SINGLEHOP        ESTABLISHED
# 34  EBGP_SINGLEHOP        ESTABLISHED
# 35  EBGP_SINGLEHOP        ESTABLISHED
# 36   EBGP_MULTIHOP        ESTABLISHED
# 37   EBGP_MULTIHOP        ESTABLISHED
# 38   EBGP_MULTIHOP        ESTABLISHED
# 39   EBGP_MULTIHOP        ESTABLISHED

# %% [markdown]
# ### Query BGP session with Established state

# %%
bgp_session_status[(bgp_session_status['Established_Status'] == 'ESTABLISHED')]
# Out:
#       Node      VRF Local_AS Local_Interface       Local_IP Remote_AS  \
# 2    leaf1  default    65101            None   172.31.255.1     65001
# 3    leaf1  default    65101            None   172.31.255.3     65001
# 4    leaf1  default    65101            None    192.0.255.3     65001
# 5    leaf1  default    65101            None    192.0.255.3     65001
# 8    leaf2  default    65101            None   172.31.255.5     65001
# 9    leaf2  default    65101            None   172.31.255.7     65001
# 10   leaf2  default    65101            None    192.0.255.4     65001
# 11   leaf2  default    65101            None    192.0.255.4     65001
# 14   leaf3  default    65102            None   172.31.255.9     65001
# 15   leaf3  default    65102            None  172.31.255.11     65001
# 16   leaf3  default    65102            None    192.0.255.5     65001
# 17   leaf3  default    65102            None    192.0.255.5     65001
# 20   leaf4  default    65102            None  172.31.255.13     65001
# 21   leaf4  default    65102            None  172.31.255.15     65001
# 22   leaf4  default    65102            None    192.0.255.6     65001
# 23   leaf4  default    65102            None    192.0.255.6     65001
# 24  spine1  default    65001            None   172.31.255.0     65101
# 25  spine1  default    65001            None   172.31.255.4     65101
# 26  spine1  default    65001            None   172.31.255.8     65102
# 27  spine1  default    65001            None  172.31.255.12     65102
# 28  spine1  default    65001            None    192.0.255.1     65101
# 29  spine1  default    65001            None    192.0.255.1     65101
# 30  spine1  default    65001            None    192.0.255.1     65102
# 31  spine1  default    65001            None    192.0.255.1     65102
# 32  spine2  default    65001            None   172.31.255.2     65101
# 33  spine2  default    65001            None   172.31.255.6     65101
# 34  spine2  default    65001            None  172.31.255.10     65102
# 35  spine2  default    65001            None  172.31.255.14     65102
# 36  spine2  default    65001            None    192.0.255.2     65101
# 37  spine2  default    65001            None    192.0.255.2     65101
# 38  spine2  default    65001            None    192.0.255.2     65102
# 39  spine2  default    65001            None    192.0.255.2     65102
#
#    Remote_Node Remote_Interface      Remote_IP  Address_Families  \
# 2       spine1             None   172.31.255.0  ['IPV4_UNICAST']
# 3       spine2             None   172.31.255.2  ['IPV4_UNICAST']
# 4       spine1             None    192.0.255.1          ['EVPN']
# 5       spine2             None    192.0.255.2          ['EVPN']
# 8       spine1             None   172.31.255.4  ['IPV4_UNICAST']
# 9       spine2             None   172.31.255.6  ['IPV4_UNICAST']
# 10      spine1             None    192.0.255.1          ['EVPN']
# 11      spine2             None    192.0.255.2          ['EVPN']
# 14      spine1             None   172.31.255.8  ['IPV4_UNICAST']
# 15      spine2             None  172.31.255.10  ['IPV4_UNICAST']
# 16      spine1             None    192.0.255.1          ['EVPN']
# 17      spine2             None    192.0.255.2          ['EVPN']
# 20      spine1             None  172.31.255.12  ['IPV4_UNICAST']
# 21      spine2             None  172.31.255.14  ['IPV4_UNICAST']
# 22      spine1             None    192.0.255.1          ['EVPN']
# 23      spine2             None    192.0.255.2          ['EVPN']
# 24       leaf1             None   172.31.255.1  ['IPV4_UNICAST']
# 25       leaf2             None   172.31.255.5  ['IPV4_UNICAST']
# 26       leaf3             None   172.31.255.9  ['IPV4_UNICAST']
# 27       leaf4             None  172.31.255.13  ['IPV4_UNICAST']
# 28       leaf1             None    192.0.255.3          ['EVPN']
# 29       leaf2             None    192.0.255.4          ['EVPN']
# 30       leaf3             None    192.0.255.5          ['EVPN']
# 31       leaf4             None    192.0.255.6          ['EVPN']
# 32       leaf1             None   172.31.255.3  ['IPV4_UNICAST']
# 33       leaf2             None   172.31.255.7  ['IPV4_UNICAST']
# 34       leaf3             None  172.31.255.11  ['IPV4_UNICAST']
# 35       leaf4             None  172.31.255.15  ['IPV4_UNICAST']
# 36       leaf1             None    192.0.255.3          ['EVPN']
# 37       leaf2             None    192.0.255.4          ['EVPN']
# 38       leaf3             None    192.0.255.5          ['EVPN']
# 39       leaf4             None    192.0.255.6          ['EVPN']
#
#       Session_Type Established_Status
# 2   EBGP_SINGLEHOP        ESTABLISHED
# 3   EBGP_SINGLEHOP        ESTABLISHED
# 4    EBGP_MULTIHOP        ESTABLISHED
# 5    EBGP_MULTIHOP        ESTABLISHED
# 8   EBGP_SINGLEHOP        ESTABLISHED
# 9   EBGP_SINGLEHOP        ESTABLISHED
# 10   EBGP_MULTIHOP        ESTABLISHED
# 11   EBGP_MULTIHOP        ESTABLISHED
# 14  EBGP_SINGLEHOP        ESTABLISHED
# 15  EBGP_SINGLEHOP        ESTABLISHED
# 16   EBGP_MULTIHOP        ESTABLISHED
# 17   EBGP_MULTIHOP        ESTABLISHED
# 20  EBGP_SINGLEHOP        ESTABLISHED
# 21  EBGP_SINGLEHOP        ESTABLISHED
# 22   EBGP_MULTIHOP        ESTABLISHED
# 23   EBGP_MULTIHOP        ESTABLISHED
# 24  EBGP_SINGLEHOP        ESTABLISHED
# 25  EBGP_SINGLEHOP        ESTABLISHED
# 26  EBGP_SINGLEHOP        ESTABLISHED
# 27  EBGP_SINGLEHOP        ESTABLISHED
# 28   EBGP_MULTIHOP        ESTABLISHED
# 29   EBGP_MULTIHOP        ESTABLISHED
# 30   EBGP_MULTIHOP        ESTABLISHED
# 31   EBGP_MULTIHOP        ESTABLISHED
# 32  EBGP_SINGLEHOP        ESTABLISHED
# 33  EBGP_SINGLEHOP        ESTABLISHED
# 34  EBGP_SINGLEHOP        ESTABLISHED
# 35  EBGP_SINGLEHOP        ESTABLISHED
# 36   EBGP_MULTIHOP        ESTABLISHED
# 37   EBGP_MULTIHOP        ESTABLISHED
# 38   EBGP_MULTIHOP        ESTABLISHED
# 39   EBGP_MULTIHOP        ESTABLISHED

# %%
bgp_edges = bfq.bgpEdges().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: TERMINATEDNORMALLY
# .... 2021-10-18 17:06:20.405000-07:00 Begin job.

# %%
bgp_edges
# Out:
#       Node             IP Interface AS_Number Remote_Node      Remote_IP  \
# 0    leaf2   172.31.255.7      None     65101      spine2   172.31.255.6
# 1    leaf4    192.0.255.6      None     65102      spine1    192.0.255.1
# 2    leaf2   172.31.255.5      None     65101      spine1   172.31.255.4
# 3   spine1   172.31.255.0      None     65001       leaf1   172.31.255.1
# 4    leaf4    192.0.255.6      None     65102      spine2    192.0.255.2
# 5    leaf2   10.255.251.1      None     65101       leaf1   10.255.251.0
# 6    leaf2   10.255.251.1      None     65101       leaf1   10.255.251.0
# 7    leaf2   10.255.251.1      None     65101       leaf1   10.255.251.0
# 8    leaf2   10.255.251.1      None     65101       leaf1   10.255.251.0
# 9    leaf2    192.0.255.4      None     65101      spine1    192.0.255.1
# 10   leaf2    192.0.255.4      None     65101      spine2    192.0.255.2
# 11  spine2   172.31.255.6      None     65001       leaf2   172.31.255.7
# 12   leaf1   10.255.251.0      None     65101       leaf2   10.255.251.1
# 13   leaf1   10.255.251.0      None     65101       leaf2   10.255.251.1
# 14   leaf1   10.255.251.0      None     65101       leaf2   10.255.251.1
# 15   leaf1   10.255.251.0      None     65101       leaf2   10.255.251.1
# 16  spine2   172.31.255.2      None     65001       leaf1   172.31.255.3
# 17   leaf4  172.31.255.15      None     65102      spine2  172.31.255.14
# 18   leaf3  172.31.255.11      None     65102      spine2  172.31.255.10
# 19   leaf4  172.31.255.13      None     65102      spine1  172.31.255.12
# 20   leaf1   172.31.255.3      None     65101      spine2   172.31.255.2
# 21   leaf3   172.31.255.9      None     65102      spine1   172.31.255.8
# 22  spine1   172.31.255.4      None     65001       leaf2   172.31.255.5
# 23  spine1    192.0.255.1      None     65001       leaf4    192.0.255.6
# 24  spine2    192.0.255.2      None     65001       leaf4    192.0.255.6
# 25  spine1   172.31.255.8      None     65001       leaf3   172.31.255.9
# 26  spine2    192.0.255.2      None     65001       leaf3    192.0.255.5
# 27  spine1    192.0.255.1      None     65001       leaf3    192.0.255.5
# 28   leaf1   172.31.255.1      None     65101      spine1   172.31.255.0
# 29  spine2  172.31.255.10      None     65001       leaf3  172.31.255.11
# 30  spine1  172.31.255.12      None     65001       leaf4  172.31.255.13
# 31  spine2  172.31.255.14      None     65001       leaf4  172.31.255.15
# 32  spine1    192.0.255.1      None     65001       leaf1    192.0.255.3
# 33   leaf3    192.0.255.5      None     65102      spine2    192.0.255.2
# 34   leaf1    192.0.255.3      None     65101      spine1    192.0.255.1
# 35   leaf3    192.0.255.5      None     65102      spine1    192.0.255.1
# 36  spine2    192.0.255.2      None     65001       leaf1    192.0.255.3
# 37  spine2    192.0.255.2      None     65001       leaf2    192.0.255.4
# 38  spine1    192.0.255.1      None     65001       leaf2    192.0.255.4
# 39   leaf3   10.255.251.4      None     65102       leaf4   10.255.251.5
# 40   leaf3   10.255.251.4      None     65102       leaf4   10.255.251.5
# 41   leaf3   10.255.251.4      None     65102       leaf4   10.255.251.5
# 42   leaf3   10.255.251.4      None     65102       leaf4   10.255.251.5
# 43   leaf4   10.255.251.5      None     65102       leaf3   10.255.251.4
# 44   leaf4   10.255.251.5      None     65102       leaf3   10.255.251.4
# 45   leaf4   10.255.251.5      None     65102       leaf3   10.255.251.4
# 46   leaf4   10.255.251.5      None     65102       leaf3   10.255.251.4
# 47   leaf1    192.0.255.3      None     65101      spine2    192.0.255.2
#
#    Remote_Interface Remote_AS_Number
# 0              None            65001
# 1              None            65001
# 2              None            65001
# 3              None            65101
# 4              None            65001
# 5              None            65101
# 6              None            65101
# 7              None            65101
# 8              None            65101
# 9              None            65001
# 10             None            65001
# 11             None            65101
# 12             None            65101
# 13             None            65101
# 14             None            65101
# 15             None            65101
# 16             None            65101
# 17             None            65001
# 18             None            65001
# 19             None            65001
# 20             None            65001
# 21             None            65001
# 22             None            65101
# 23             None            65102
# 24             None            65102
# 25             None            65102
# 26             None            65102
# 27             None            65102
# 28             None            65001
# 29             None            65102
# 30             None            65102
# 31             None            65102
# 32             None            65101
# 33             None            65001
# 34             None            65001
# 35             None            65001
# 36             None            65101
# 37             None            65101
# 38             None            65101
# 39             None            65102
# 40             None            65102
# 41             None            65102
# 42             None            65102
# 43             None            65102
# 44             None            65102
# 45             None            65102
# 46             None            65102
# 47             None            65001

# %%
bgp_rib = bfq.bgpRib().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: ASSIGNED
# .... 2021-10-18 17:09:35.554000-07:00 Loading data plane from disk.
# status: TERMINATEDNORMALLY
# .... 2021-10-18 17:09:35.554000-07:00 Loading data plane from disk.

# %%
bgp_rib
# Out:
#        Node               VRF         Network    Next_Hop_IP  \
# 0     leaf4           default  192.0.255.1/32  172.31.255.12
# 1    spine2           default  192.0.254.5/32  172.31.255.11
# 2    spine2           default  192.0.254.5/32  172.31.255.15
# 3     leaf3  Tenant_A_OP_Zone  192.0.255.3/32   10.255.251.5
# 4    spine1           default   10.255.1.6/32   172.31.255.9
# ..      ...               ...             ...            ...
# 151   leaf3  Tenant_A_OP_Zone    10.1.10.0/24   10.255.251.5
# 152   leaf2           default   10.255.1.5/32   172.31.255.6
# 153  spine1           default  192.0.255.5/32   172.31.255.9
# 154   leaf2  Tenant_A_OP_Zone  192.0.255.5/32   10.255.251.0
# 155   leaf4           default   10.255.1.3/32  172.31.255.14
#
#     Next_Hop_Interface Protocol      AS_Path Metric Local_Pref Communities  \
# 0              dynamic      bgp        65001      0        100          []
# 1              dynamic      bgp        65102      0        100          []
# 2              dynamic      bgp        65102      0        100          []
# 3              dynamic     ibgp  65001 65101      0        100          []
# 4              dynamic      bgp        65102      0        100          []
# ..                 ...      ...          ...    ...        ...         ...
# 151            dynamic     ibgp                   0        100          []
# 152            dynamic      bgp  65001 65102      0        100          []
# 153            dynamic      bgp        65102      0        100          []
# 154            dynamic     ibgp  65001 65102      0        100          []
# 155            dynamic      bgp  65001 65101      0        100          []
#
#     Origin_Protocol Origin_Type Originator_Id Cluster_List   Tag
# 0               bgp  incomplete   192.0.255.1         None  None
# 1               bgp  incomplete   192.0.255.5         None  None
# 2               bgp  incomplete   192.0.255.6         None  None
# 3              ibgp  incomplete   192.0.255.6         None  None
# 4               bgp  incomplete   192.0.255.5         None  None
# ..              ...         ...           ...          ...   ...
# 151            ibgp  incomplete   192.0.255.6         None  None
# 152             bgp  incomplete   192.0.255.2         None  None
# 153             bgp  incomplete   192.0.255.5         None  None
# 154            ibgp  incomplete   192.0.255.3         None  None
# 155             bgp  incomplete   192.0.255.2         None  None
#
# [156 rows x 15 columns]

# %%
bgp_peer_config = bfq.bgpPeerConfiguration().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: TERMINATEDNORMALLY
# .... 2021-10-18 17:11:17.285000-07:00 Begin job.

# %%
bgp_peer_config
# Out:
#       Node               VRF Local_AS       Local_IP Local_Interface  \
# 0   spine1           default    65001    192.0.255.1            None
# 1    leaf4           default    65102  172.31.255.15            None
# 2   spine2           default    65001    192.0.255.2            None
# 3    leaf2           default    65101   10.255.251.1            None
# 4   spine1           default    65001    192.0.255.1            None
# 5   spine2           default    65001  172.31.255.14            None
# 6    leaf2           default    65101   172.31.255.7            None
# 7   spine2           default    65001    192.0.255.2            None
# 8   spine2           default    65001   172.31.255.2            None
# 9   spine1           default    65001    192.0.255.1            None
# 10  spine2           default    65001    192.0.255.2            None
# 11  spine1           default    65001   172.31.255.0            None
# 12   leaf3           default    65102  172.31.255.11            None
# 13  spine2           default    65001    192.0.255.2            None
# 14  spine2           default    65001   172.31.255.6            None
# 15  spine1           default    65001   172.31.255.4            None
# 16  spine1           default    65001  172.31.255.12            None
# 17   leaf1           default    65101   172.31.255.3            None
# 18   leaf2  Tenant_A_OP_Zone    65101   10.255.251.1            None
# 19   leaf4           default    65102    192.0.255.6            None
# 20  spine1           default    65001   172.31.255.8            None
# 21   leaf1           default    65101   172.31.255.1            None
# 22   leaf4           default    65102    192.0.255.6            None
# 23   leaf1  Tenant_A_OP_Zone    65101   10.255.251.0            None
# 24   leaf3  Tenant_A_OP_Zone    65102   10.255.251.4            None
# 25   leaf3           default    65102   172.31.255.9            None
# 26  spine2           default    65001  172.31.255.10            None
# 27   leaf3           default    65102    192.0.255.5            None
# 28   leaf4  Tenant_A_OP_Zone    65102   10.255.251.5            None
# 29   leaf1           default    65101    192.0.255.3            None
# 30   leaf4           default    65102  172.31.255.13            None
# 31   leaf3           default    65102    192.0.255.5            None
# 32   leaf1           default    65101    192.0.255.3            None
# 33   leaf2           default    65101   172.31.255.5            None
# 34   leaf1           default    65101   10.255.251.0            None
# 35   leaf4           default    65102   10.255.251.5            None
# 36   leaf2           default    65101    192.0.255.4            None
# 37   leaf2           default    65101    192.0.255.4            None
# 38  spine1           default    65001    192.0.255.1            None
# 39   leaf3           default    65102   10.255.251.4            None
#
#    Confederation Remote_AS      Remote_IP       Description  \
# 0           None     65102    192.0.255.5             leaf3
# 1           None     65001  172.31.255.14  spine2_Ethernet5
# 2           None     65101    192.0.255.4             leaf2
# 3           None     65101   10.255.251.0             leaf1
# 4           None     65101    192.0.255.3             leaf1
# 5           None     65102  172.31.255.15   leaf4_Ethernet5
# 6           None     65001   172.31.255.6  spine2_Ethernet3
# 7           None     65102    192.0.255.5             leaf3
# 8           None     65101   172.31.255.3   leaf1_Ethernet2
# 9           None     65102    192.0.255.6             leaf4
# 10          None     65101    192.0.255.3             leaf1
# 11          None     65101   172.31.255.1   leaf1_Ethernet2
# 12          None     65001  172.31.255.10  spine2_Ethernet4
# 13          None     65102    192.0.255.6             leaf4
# 14          None     65101   172.31.255.7   leaf2_Ethernet3
# 15          None     65101   172.31.255.5   leaf2_Ethernet3
# 16          None     65102  172.31.255.13   leaf4_Ethernet5
# 17          None     65001   172.31.255.2  spine2_Ethernet2
# 18          None     65101   10.255.251.0              None
# 19          None     65001    192.0.255.2            spine2
# 20          None     65102   172.31.255.9   leaf3_Ethernet4
# 21          None     65001   172.31.255.0  spine1_Ethernet2
# 22          None     65001    192.0.255.1            spine1
# 23          None     65101   10.255.251.1              None
# 24          None     65102   10.255.251.5              None
# 25          None     65001   172.31.255.8  spine1_Ethernet4
# 26          None     65102  172.31.255.11   leaf3_Ethernet4
# 27          None     65001    192.0.255.2            spine2
# 28          None     65102   10.255.251.4              None
# 29          None     65001    192.0.255.2            spine2
# 30          None     65001  172.31.255.12  spine1_Ethernet5
# 31          None     65001    192.0.255.1            spine1
# 32          None     65001    192.0.255.1            spine1
# 33          None     65001   172.31.255.4  spine1_Ethernet3
# 34          None     65101   10.255.251.1             leaf2
# 35          None     65102   10.255.251.4             leaf3
# 36          None     65001    192.0.255.2            spine2
# 37          None     65001    192.0.255.1            spine1
# 38          None     65101    192.0.255.4             leaf2
# 39          None     65102   10.255.251.5             leaf4
#
#    Route_Reflector_Client Cluster_ID               Peer_Group  \
# 0                   False       None       EVPN-OVERLAY-PEERS
# 1                   False       None      IPv4-UNDERLAY-PEERS
# 2                   False       None       EVPN-OVERLAY-PEERS
# 3                   False       None  MLAG-IPv4-UNDERLAY-PEER
# 4                   False       None       EVPN-OVERLAY-PEERS
# 5                   False       None      IPv4-UNDERLAY-PEERS
# 6                   False       None      IPv4-UNDERLAY-PEERS
# 7                   False       None       EVPN-OVERLAY-PEERS
# 8                   False       None      IPv4-UNDERLAY-PEERS
# 9                   False       None       EVPN-OVERLAY-PEERS
# 10                  False       None       EVPN-OVERLAY-PEERS
# 11                  False       None      IPv4-UNDERLAY-PEERS
# 12                  False       None      IPv4-UNDERLAY-PEERS
# 13                  False       None       EVPN-OVERLAY-PEERS
# 14                  False       None      IPv4-UNDERLAY-PEERS
# 15                  False       None      IPv4-UNDERLAY-PEERS
# 16                  False       None      IPv4-UNDERLAY-PEERS
# 17                  False       None      IPv4-UNDERLAY-PEERS
# 18                  False       None  MLAG-IPv4-UNDERLAY-PEER
# 19                  False       None       EVPN-OVERLAY-PEERS
# 20                  False       None      IPv4-UNDERLAY-PEERS
# 21                  False       None      IPv4-UNDERLAY-PEERS
# 22                  False       None       EVPN-OVERLAY-PEERS
# 23                  False       None  MLAG-IPv4-UNDERLAY-PEER
# 24                  False       None  MLAG-IPv4-UNDERLAY-PEER
# 25                  False       None      IPv4-UNDERLAY-PEERS
# 26                  False       None      IPv4-UNDERLAY-PEERS
# 27                  False       None       EVPN-OVERLAY-PEERS
# 28                  False       None  MLAG-IPv4-UNDERLAY-PEER
# 29                  False       None       EVPN-OVERLAY-PEERS
# 30                  False       None      IPv4-UNDERLAY-PEERS
# 31                  False       None       EVPN-OVERLAY-PEERS
# 32                  False       None       EVPN-OVERLAY-PEERS
# 33                  False       None      IPv4-UNDERLAY-PEERS
# 34                  False       None  MLAG-IPv4-UNDERLAY-PEER
# 35                  False       None  MLAG-IPv4-UNDERLAY-PEER
# 36                  False       None       EVPN-OVERLAY-PEERS
# 37                  False       None       EVPN-OVERLAY-PEERS
# 38                  False       None       EVPN-OVERLAY-PEERS
# 39                  False       None  MLAG-IPv4-UNDERLAY-PEER
#
#           Import_Policy      Export_Policy Send_Community Is_Passive
# 0                    []                 []          False      False
# 1                    []  ['RM-CONN-2-BGP']           True      False
# 2                    []                 []          False      False
# 3   ['RM-MLAG-PEER-IN']  ['RM-CONN-2-BGP']           True      False
# 4                    []                 []          False      False
# 5                    []  ['RM-CONN-2-BGP']           True      False
# 6                    []  ['RM-CONN-2-BGP']           True      False
# 7                    []                 []          False      False
# 8                    []  ['RM-CONN-2-BGP']           True      False
# 9                    []                 []          False      False
# 10                   []                 []          False      False
# 11                   []  ['RM-CONN-2-BGP']           True      False
# 12                   []  ['RM-CONN-2-BGP']           True      False
# 13                   []                 []          False      False
# 14                   []  ['RM-CONN-2-BGP']           True      False
# 15                   []  ['RM-CONN-2-BGP']           True      False
# 16                   []  ['RM-CONN-2-BGP']           True      False
# 17                   []  ['RM-CONN-2-BGP']           True      False
# 18  ['RM-MLAG-PEER-IN']                 []           True      False
# 19                   []                 []          False      False
# 20                   []  ['RM-CONN-2-BGP']           True      False
# 21                   []  ['RM-CONN-2-BGP']           True      False
# 22                   []                 []          False      False
# 23  ['RM-MLAG-PEER-IN']                 []           True      False
# 24  ['RM-MLAG-PEER-IN']                 []           True      False
# 25                   []  ['RM-CONN-2-BGP']           True      False
# 26                   []  ['RM-CONN-2-BGP']           True      False
# 27                   []                 []          False      False
# 28  ['RM-MLAG-PEER-IN']                 []           True      False
# 29                   []                 []          False      False
# 30                   []  ['RM-CONN-2-BGP']           True      False
# 31                   []                 []          False      False
# 32                   []                 []          False      False
# 33                   []  ['RM-CONN-2-BGP']           True      False
# 34  ['RM-MLAG-PEER-IN']  ['RM-CONN-2-BGP']           True      False
# 35  ['RM-MLAG-PEER-IN']  ['RM-CONN-2-BGP']           True      False
# 36                   []                 []          False      False
# 37                   []                 []          False      False
# 38                   []                 []          False      False
# 39  ['RM-MLAG-PEER-IN']  ['RM-CONN-2-BGP']           True      False

# %%
bfq.bgpProcessConfiguration().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: TERMINATEDNORMALLY
# .... 2021-10-18 17:14:52.901000-07:00 Begin job.
#      Node               VRF    Router_ID Confederation_ID  \
# 0   leaf1  Tenant_A_OP_Zone  192.0.255.3             None
# 1   leaf3  Tenant_A_OP_Zone  192.0.255.5             None
# 2   leaf3           default  192.0.255.5             None
# 3   leaf2  Tenant_A_OP_Zone  192.0.255.4             None
# 4  spine1           default  192.0.255.1             None
# 5  spine2           default  192.0.255.2             None
# 6   leaf1           default  192.0.255.3             None
# 7   leaf4  Tenant_A_OP_Zone  192.0.255.6             None
# 8   leaf4           default  192.0.255.6             None
# 9   leaf2           default  192.0.255.4             None
#
#   Confederation_Members Multipath_EBGP Multipath_IBGP Multipath_Match_Mode  \
# 0                  None          False          False          PATH_LENGTH
# 1                  None          False          False          PATH_LENGTH
# 2                  None           True           True          PATH_LENGTH
# 3                  None          False          False          PATH_LENGTH
# 4                  None           True           True          PATH_LENGTH
# 5                  None           True           True          PATH_LENGTH
# 6                  None           True           True          PATH_LENGTH
# 7                  None          False          False          PATH_LENGTH
# 8                  None           True           True          PATH_LENGTH
# 9                  None           True           True          PATH_LENGTH
#
#                                            Neighbors Route_Reflector  \
# 0                                ['10.255.251.1/32']           False
# 1                                ['10.255.251.5/32']           False
# 2  ['10.255.251.5/32', '172.31.255.8/32', '172.31...           False
# 3                                ['10.255.251.0/32']           False
# 4  ['172.31.255.1/32', '172.31.255.5/32', '172.31...           False
# 5  ['172.31.255.3/32', '172.31.255.7/32', '172.31...           False
# 6  ['10.255.251.1/32', '172.31.255.0/32', '172.31...           False
# 7                                ['10.255.251.4/32']           False
# 8  ['10.255.251.4/32', '172.31.255.12/32', '172.3...           False
# 9  ['10.255.251.0/32', '172.31.255.4/32', '172.31...           False
#
#   Tie_Breaker
# 0   ROUTER_ID
# 1   ROUTER_ID
# 2   ROUTER_ID
# 3   ROUTER_ID
# 4   ROUTER_ID
# 5   ROUTER_ID
# 6   ROUTER_ID
# 7   ROUTER_ID
# 8   ROUTER_ID
# 9   ROUTER_ID

# %% [markdown]
# ## Routing and Forwarding Tables Questions

# %% [markdown]
# ### EVPN RIB

# %%
bfq.evpnRib().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: TERMINATEDNORMALLY
# .... 2021-10-18 17:19:48.543000-07:00 Begin job.
#      Node               VRF         Network Route_Distinguisher  \
# 0   leaf1  Tenant_A_OP_Zone  192.0.254.5/32      192.0.255.6:10
# 1   leaf1  Tenant_A_OP_Zone  192.0.254.5/32      192.0.255.6:10
# 2   leaf2  Tenant_A_OP_Zone  192.0.254.5/32      192.0.255.5:10
# 3   leaf4  Tenant_A_OP_Zone  192.0.254.3/32      192.0.255.4:10
# 4   leaf1  Tenant_A_OP_Zone  192.0.254.3/32      192.0.255.3:10
# 5   leaf2  Tenant_A_OP_Zone  192.0.254.5/32      192.0.255.5:10
# 6   leaf3  Tenant_A_OP_Zone  192.0.254.3/32      192.0.255.4:10
# 7   leaf4  Tenant_A_OP_Zone  192.0.254.3/32      192.0.255.4:10
# 8   leaf3  Tenant_A_OP_Zone  192.0.254.3/32      192.0.255.4:10
# 9   leaf1  Tenant_A_OP_Zone  192.0.254.5/32      192.0.255.5:10
# 10  leaf4  Tenant_A_OP_Zone  192.0.254.5/32      192.0.255.6:10
# 11  leaf3  Tenant_A_OP_Zone  192.0.254.5/32      192.0.255.5:10
# 12  leaf4  Tenant_A_OP_Zone  192.0.254.3/32      192.0.255.3:10
# 13  leaf2  Tenant_A_OP_Zone  192.0.254.5/32      192.0.255.6:10
# 14  leaf3  Tenant_A_OP_Zone  192.0.254.3/32      192.0.255.3:10
# 15  leaf1  Tenant_A_OP_Zone  192.0.254.5/32      192.0.255.5:10
# 16  leaf4  Tenant_A_OP_Zone  192.0.254.3/32      192.0.255.3:10
# 17  leaf2  Tenant_A_OP_Zone  192.0.254.5/32      192.0.255.6:10
# 18  leaf3  Tenant_A_OP_Zone  192.0.254.3/32      192.0.255.3:10
# 19  leaf2  Tenant_A_OP_Zone  192.0.254.3/32      192.0.255.4:10
#
#        Next_Hop_IP Next_Hop_Interface Protocol      AS_Path Metric Local_Pref  \
# 0      192.0.255.6            dynamic      bgp  65001 65102      0        100
# 1      192.0.255.6            dynamic      bgp  65001 65102      0        100
# 2      192.0.255.5            dynamic      bgp  65001 65102      0        100
# 3      192.0.255.4            dynamic      bgp  65001 65101      0        100
# 4   AUTO/NONE(-1l)     null_interface      bgp                   0        100
# 5      192.0.255.5            dynamic      bgp  65001 65102      0        100
# 6      192.0.255.4            dynamic      bgp  65001 65101      0        100
# 7      192.0.255.4            dynamic      bgp  65001 65101      0        100
# 8      192.0.255.4            dynamic      bgp  65001 65101      0        100
# 9      192.0.255.5            dynamic      bgp  65001 65102      0        100
# 10  AUTO/NONE(-1l)     null_interface      bgp                   0        100
# 11  AUTO/NONE(-1l)     null_interface      bgp                   0        100
# 12     192.0.255.3            dynamic      bgp  65001 65101      0        100
# 13     192.0.255.6            dynamic      bgp  65001 65102      0        100
# 14     192.0.255.3            dynamic      bgp  65001 65101      0        100
# 15     192.0.255.5            dynamic      bgp  65001 65102      0        100
# 16     192.0.255.3            dynamic      bgp  65001 65101      0        100
# 17     192.0.255.6            dynamic      bgp  65001 65102      0        100
# 18     192.0.255.3            dynamic      bgp  65001 65101      0        100
# 19  AUTO/NONE(-1l)     null_interface      bgp                   0        100
#
#     Communities Origin_Protocol Origin_Type Originator_Id Cluster_List   Tag
# 0   ['2:10:10']             bgp         egp   192.0.255.1         None  None
# 1   ['2:10:10']             bgp         egp   192.0.255.2         None  None
# 2   ['2:10:10']             bgp         egp   192.0.255.1         None  None
# 3   ['2:10:10']             bgp         egp   192.0.255.1         None  None
# 4   ['2:10:10']            None         egp   192.0.255.3         None  None
# 5   ['2:10:10']             bgp         egp   192.0.255.2         None  None
# 6   ['2:10:10']             bgp         egp   192.0.255.1         None  None
# 7   ['2:10:10']             bgp         egp   192.0.255.2         None  None
# 8   ['2:10:10']             bgp         egp   192.0.255.2         None  None
# 9   ['2:10:10']             bgp         egp   192.0.255.1         None  None
# 10  ['2:10:10']            None         egp   192.0.255.6         None  None
# 11  ['2:10:10']            None         egp   192.0.255.5         None  None
# 12  ['2:10:10']             bgp         egp   192.0.255.2         None  None
# 13  ['2:10:10']             bgp         egp   192.0.255.1         None  None
# 14  ['2:10:10']             bgp         egp   192.0.255.1         None  None
# 15  ['2:10:10']             bgp         egp   192.0.255.2         None  None
# 16  ['2:10:10']             bgp         egp   192.0.255.1         None  None
# 17  ['2:10:10']             bgp         egp   192.0.255.2         None  None
# 18  ['2:10:10']             bgp         egp   192.0.255.2         None  None
# 19  ['2:10:10']            None         egp   192.0.255.4         None  None

# %% [markdown]
# ### Routes

# %%
bfq.routes().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: TERMINATEDNORMALLY
# .... 2021-10-18 17:21:34.036000-07:00 Begin job.
#       Node               VRF         Network Next_Hop   Next_Hop_IP  \
# 0    leaf4  Tenant_A_OP_Zone  192.0.255.1/32    leaf3  10.255.251.4
# 1    leaf2  Tenant_A_OP_Zone  192.0.254.3/32    leaf1  10.255.251.0
# 2    leaf4  Tenant_A_OP_Zone   10.255.1.5/32    leaf3  10.255.251.4
# 3    leaf3  Tenant_A_OP_Zone  192.0.255.1/32    leaf4  10.255.251.5
# 4    leaf4           default  192.0.255.5/32    leaf3  10.255.251.4
# ..     ...               ...             ...      ...           ...
# 213  leaf2           default  192.0.255.6/32   spine1  172.31.255.4
# 214  leaf4  Tenant_A_OP_Zone  192.0.255.3/32    leaf3  10.255.251.4
# 215  leaf1           default  192.0.255.6/32   spine1  172.31.255.0
# 216  leaf2           default  192.0.255.6/32   spine2  172.31.255.6
# 217  leaf1           default   10.255.1.5/32   spine2  172.31.255.2
#
#     Next_Hop_Interface Protocol Metric Admin_Distance   Tag
# 0              dynamic     ibgp      0            200  None
# 1              dynamic     ibgp      0            200  None
# 2              dynamic     ibgp      0            200  None
# 3              dynamic     ibgp      0            200  None
# 4              dynamic     ibgp      0            200  None
# ..                 ...      ...    ...            ...   ...
# 213            dynamic      bgp      0             20  None
# 214            dynamic     ibgp      0            200  None
# 215            dynamic      bgp      0             20  None
# 216            dynamic      bgp      0             20  None
# 217            dynamic      bgp      0             20  None
#
# [218 rows x 10 columns]

# %% [markdown]
# ### Longest Prefix Matching

# %%
bfq.lpmRoutes(ip='10.255.251.4').answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: TERMINATEDNORMALLY
# .... 2021-10-18 17:24:04.867000-07:00 Begin job.
#     Node               VRF            Ip          Network Num_Routes
# 0  leaf3  Tenant_A_OP_Zone  10.255.251.4  10.255.251.4/32          1
# 1  leaf3           default  10.255.251.4  10.255.251.4/32          1
# 2  leaf4  Tenant_A_OP_Zone  10.255.251.4  10.255.251.4/31          1
# 3  leaf4           default  10.255.251.4  10.255.251.4/31          1

# %% [markdown]
# ## Packet Forwarding Questions

# %% [markdown]
# ### Loop Detection

# %%
pd.set_option('display.max_colwidth', 100)
bfq.detectLoops().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: TERMINATEDNORMALLY
# .... 2021-10-18 18:00:53.502000-07:00 Begin job.
#                                                                         Flow  \
# 0  start=leaf1 vrf=Tenant_A_OP_Zone [10.1.10.1->192.0.254.3 ICMP length=512]
# 1                       start=leaf1 [192.0.254.3->10.1.10.0 ICMP length=512]
#
#                                                                                                 Traces  \
# 0  [((ORIGINATED(Tenant_A_OP_Zone), FORWARDED(ARP IP: 10.255.251.1, Output Interface: Vlan3009, Rou...
# 1  [((ORIGINATED(default), FORWARDED(ARP IP: 10.255.251.1, Output Interface: Vlan4093, Routes: [ibg...
#
#   TraceCount
# 0          4
# 1          4

# %% [markdown]
# ### Host subnet multipath consinstency check

# %%
bfq.subnetMultipathConsistency().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: ASSIGNED
# .... 2021-10-18 17:40:36.846000-07:00 Begin job.
# status: TERMINATEDNORMALLY
# .... 2021-10-18 17:40:36.846000-07:00 Begin job.
# Empty DataFrame
# Columns: [Flow, Traces, TraceCount]
# Index: []

# %% [markdown]
# ### Loopback multipath consistency check

# %%
loopback_mp_consistency = bfq.loopbackMultipathConsistency().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: ASSIGNED
# .... 2021-10-18 17:43:05.934000-07:00 Begin job.
# status: TERMINATEDNORMALLY
# .... 2021-10-18 17:43:05.934000-07:00 Begin job.

# %%
pd.set_option('display.max_colwidth', 100)
loopback_mp_consistency
# Out:
#                                                                          Flow  \
# 0  start=leaf1 vrf=Tenant_A_OP_Zone [10.255.1.3->192.0.254.3 ICMP length=512]
# 1                       start=leaf1 [192.0.254.3->10.255.1.4 ICMP length=512]
# 2  start=leaf2 vrf=Tenant_A_OP_Zone [10.255.1.4->192.0.254.3 ICMP length=512]
# 3                       start=leaf2 [192.0.254.3->10.255.1.3 ICMP length=512]
# 4  start=leaf3 vrf=Tenant_A_OP_Zone [10.255.1.5->192.0.254.3 ICMP length=512]
# 5                       start=leaf3 [192.0.254.5->10.255.1.3 ICMP length=512]
# 6  start=leaf4 vrf=Tenant_A_OP_Zone [10.255.1.6->192.0.254.3 ICMP length=512]
# 7                       start=leaf4 [192.0.254.5->10.255.1.3 ICMP length=512]
# 8                      start=spine1 [192.0.255.1->10.255.1.3 ICMP length=512]
# 9                      start=spine2 [192.0.255.2->10.255.1.3 ICMP length=512]
#
#                                                                                                 Traces  \
# 0  [((ORIGINATED(Tenant_A_OP_Zone), FORWARDED(ARP IP: 10.255.251.1, Output Interface: Vlan3009, Rou...
# 1  [((ORIGINATED(default), FORWARDED(ARP IP: 10.255.251.1, Output Interface: Vlan4093, Routes: [ibg...
# 2  [((ORIGINATED(Tenant_A_OP_Zone), FORWARDED(ARP IP: 10.255.251.0, Output Interface: Vlan3009, Rou...
# 3  [((ORIGINATED(default), FORWARDED(ARP IP: 10.255.251.0, Output Interface: Vlan4093, Routes: [ibg...
# 4  [((ORIGINATED(Tenant_A_OP_Zone), FORWARDED(ARP IP: 10.255.251.5, Output Interface: Vlan3009, Rou...
# 5  [((ORIGINATED(default), FORWARDED(ARP IP: 172.31.255.8, Output Interface: Ethernet2, Routes: [bg...
# 6  [((ORIGINATED(Tenant_A_OP_Zone), FORWARDED(ARP IP: 10.255.251.4, Output Interface: Vlan3009, Rou...
# 7  [((ORIGINATED(default), FORWARDED(ARP IP: 172.31.255.12, Output Interface: Ethernet2, Routes: [b...
# 8  [((ORIGINATED(default), FORWARDED(ARP IP: 172.31.255.5, Output Interface: Ethernet3, Routes: [bg...
# 9  [((ORIGINATED(default), FORWARDED(ARP IP: 172.31.255.7, Output Interface: Ethernet3, Routes: [bg...
#
#   TraceCount
# 0          4
# 1          2
# 2          4
# 3          2
# 4         13
# 5          4
# 6         13
# 7          4
# 8          2
# 9          2

# %% [markdown]
# ## Access List and Firewall Rules Questions

# %%
bfq.filterLineReachability().answer().frame()
# Out:
# status: TRYINGTOASSIGN
# .... no task information
# status: TERMINATEDNORMALLY
# .... 2021-10-18 17:56:01.971000-07:00 Begin job.
# Empty DataFrame
# Columns: [Sources, Unreachable_Line, Unreachable_Line_Action, Blocking_Lines, Different_Action, Reason, Additional_Info]
# Index: []
